# %%
#Import necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#load the dataset using pandas library

df=pd.read_csv("AUDI.csv")

# %%
#to view all the present entries in dataset

df
# Out:
#        Engine rpm  Lub oil pressure  Fuel pressure  Coolant pressure  \
# 0             700          2.493592      11.790927          3.178981
# 1             876          2.941606      16.193866          2.464504
# 2             520          2.961746       6.553147          1.064347
# 3             473          3.707835      19.510172          3.727455
# 4             619          5.672919      15.738871          2.052251
# ...           ...               ...            ...               ...
# 19530         902          4.117296       4.981360          4.346564
# 19531         694          4.817720      10.866701          6.186689
# 19532         684          2.673344       4.927376          1.903572
# 19533         696          3.094163       8.291816          1.221729
# 19534         504          3.775246       3.962480          2.038647
#
#        lub oil temp  Coolant temp  Engine Condition
# 0         84.144163     81.632187                 1
# ...

# %%
#to view the total number of entries in the columns

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19535 entries, 0 to 19534
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Engine rpm        19535 non-null  int64
#  1   Lub oil pressure  19535 non-null  float64
#  2   Fuel pressure     19535 non-null  float64
#  3   Coolant pressure  19535 non-null  float64
#  4   lub oil temp      19535 non-null  float64
#  5   Coolant temp      19535 non-null  float64
#  6   Engine Condition  19535 non-null  int64
# dtypes: float64(5), int64(2)
# memory usage: 1.0 MB

# %%
#display first 80 entries in the dataset

df.head(80)
# Out:
#     Engine rpm  Lub oil pressure  Fuel pressure  Coolant pressure  \
# 0          700          2.493592      11.790927          3.178981
# 1          876          2.941606      16.193866          2.464504
# 2          520          2.961746       6.553147          1.064347
# 3          473          3.707835      19.510172          3.727455
# 4          619          5.672919      15.738871          2.052251
# ..         ...               ...            ...               ...
# 75         864          3.265052       3.891606          1.399021
# 76        1108          3.587614       7.152264          1.504648
# 77         438          2.874118       6.377823          2.203024
# 78         678          2.061298       8.749673          1.763733
# 79         795          3.656956       6.081633          4.643739
#
#     lub oil temp  Coolant temp  Engine Condition
# 0      84.144163     81.632187                 1
# 1      77.640934     82.445724                 0
# ...

# %%
#displays last 50 entries in the dataset

df.tail(50)
# Out:
#        Engine rpm  Lub oil pressure  Fuel pressure  Coolant pressure  \
# 19485         486          4.384494       7.561094          2.844382
# 19486         902          1.245728       5.847138          1.022217
# 19487         408          2.305619       4.009057          2.049261
# 19488        1406          2.791919       9.421817          2.771362
# 19489         581          3.346339       7.098358          2.447289
# 19490        1335          1.858533       6.578615          3.158061
# 19491         680          2.499519       8.196351          1.317740
# 19492        1200          3.006065       6.657061          3.155488
# 19493         478          5.423971       7.508909          2.557160
# 19494         649          2.980596       7.110046          2.781761
# 19495         760          3.290331       5.461292          2.191933
# 19496         480          5.014930       7.793114          1.144499
# 19497         536          2.542326       7.481426          1.258722
# ...

# %%
#to view the null values

df.isnull()
# Out:
#        Engine rpm  Lub oil pressure  Fuel pressure  Coolant pressure  \
# 0           False             False          False             False
# 1           False             False          False             False
# 2           False             False          False             False
# 3           False             False          False             False
# 4           False             False          False             False
# ...           ...               ...            ...               ...
# 19530       False             False          False             False
# 19531       False             False          False             False
# 19532       False             False          False             False
# 19533       False             False          False             False
# 19534       False             False          False             False
#
#        lub oil temp  Coolant temp  Engine Condition
# 0             False         False             False
# ...

# %%
#returns the description of the dataset

df.describe()
# Out:
#          Engine rpm  Lub oil pressure  Fuel pressure  Coolant pressure  \
# count  19535.000000      19535.000000   19535.000000      19535.000000
# mean     791.239263          3.303775       6.655615          2.335369
# std      267.611193          1.021643       2.761021          1.036382
# min       61.000000          0.003384       0.003187          0.002483
# 25%      593.000000          2.518815       4.916886          1.600466
# 50%      746.000000          3.162035       6.201720          2.166883
# 75%      934.000000          4.055272       7.744973          2.848840
# max     2239.000000          7.265566      21.138326          7.478505
#
#        lub oil temp  Coolant temp  Engine Condition
# count  19535.000000  19535.000000      19535.000000
# mean      77.643420     78.427433          0.630509
# std        3.110984      6.206749          0.482679
# min       71.321974     61.673325          0.000000
# 25%       75.725990     73.895421          0.000000
# ...

# %%
# sum of entries within the null values

df.isnull().sum()
# Out:
# Engine rpm          0
# Lub oil pressure    0
# Fuel pressure       0
# Coolant pressure    0
# lub oil temp        0
# Coolant temp        0
# Engine Condition    0
# dtype: int64

# %%
#sum of entries within the values which are not null

df.notnull().sum()
# Out:
# Engine rpm          19535
# Lub oil pressure    19535
# Fuel pressure       19535
# Coolant pressure    19535
# lub oil temp        19535
# Coolant temp        19535
# Engine Condition    19535
# dtype: int64

# %%
#DATA STANDARDIZATION
#create a new column 'New value' and enter the value from 'Engine rpm' divided by 2

df['New value'] = 2/df["Engine rpm"]
df.head(80)
# Out:
#     Engine rpm  Lub oil pressure  Fuel pressure  Coolant pressure  \
# 0          700          2.493592      11.790927          3.178981
# 1          876          2.941606      16.193866          2.464504
# 2          520          2.961746       6.553147          1.064347
# 3          473          3.707835      19.510172          3.727455
# 4          619          5.672919      15.738871          2.052251
# ..         ...               ...            ...               ...
# 75         864          3.265052       3.891606          1.399021
# 76        1108          3.587614       7.152264          1.504648
# 77         438          2.874118       6.377823          2.203024
# 78         678          2.061298       8.749673          1.763733
# 79         795          3.656956       6.081633          4.643739
#
#     lub oil temp  Coolant temp  Engine Condition  New value
# 0      84.144163     81.632187                 1   0.002857
# ...

# %%
#DATA NORMALIZATION
